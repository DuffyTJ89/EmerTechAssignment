# %% [markdown]
# # <center><font color='Red' text align='center'>The Iris Dataset</font></center>
#
# ![Iris flowers](https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Machine+Learning+R/iris-machinelearning.png)
#
# The Iris dataset is made up of three different types of irises, namely Setosa, Versicolour and Virginica, with their petal and sepal length stored in an array. This notebook will aim to explain the dataset and cover the difficulty in writing an algorithm to seperate the three classes of iris mentioned above based on the variables in the dataset.

# %%
# Import pandas. Provides conversion to and from pamdas data structures
import pandas as pd

# Load the iris data set from a URL.
df = pd.read_csv("https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv")

# Display the dataset
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %% [markdown]
# ### <font color='Red'>Using the dataset</font>
# #### Selecting rows and columns

# %%
# return the Id and the type of iris it is
df['species']
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
# 5         setosa
# 6         setosa
# 7         setosa
# 8         setosa
# 9         setosa
# 10        setosa
# 11        setosa
# 12        setosa
# 13        setosa
# 14        setosa
# 15        setosa
# 16        setosa
# 17        setosa
# 18        setosa
# 19        setosa
# 20        setosa
# 21        setosa
# 22        setosa
# 23        setosa
# 24        setosa
# 25        setosa
# 26        setosa
# 27        setosa
# 28        setosa
# 29        setosa
#          ...
# 120    virginica
# 121    virginica
# 122    virginica
# 123    virginica
# 124    virginica
# 125    virginica
# 126    virginica
# 127    virginica
# 128    virginica
# 129    virginica
# 130    virginica
# 131    virginica
# 132    virginica
# 133    virginica
# 134    virginica
# 135    virginica
# 136    virginica
# 137    virginica
# 138    virginica
# 139    virginica
# 140    virginica
# ...

# %% [markdown]
# Below we will include the data about the length of the petal and the species that petal belongs to. There are differences seen here between the species in petal length but we need to visualize it better to show that there is actually not enough here to seperate them.

# %%
df[['petal_length', 'species']]
# Out:
#      petal_length    species
# 0             1.4     setosa
# 1             1.4     setosa
# 2             1.3     setosa
# 3             1.5     setosa
# 4             1.4     setosa
# 5             1.7     setosa
# 6             1.4     setosa
# 7             1.5     setosa
# 8             1.4     setosa
# 9             1.5     setosa
# 10            1.5     setosa
# 11            1.6     setosa
# 12            1.4     setosa
# 13            1.1     setosa
# 14            1.2     setosa
# 15            1.5     setosa
# 16            1.3     setosa
# 17            1.4     setosa
# 18            1.7     setosa
# 19            1.5     setosa
# 20            1.7     setosa
# 21            1.5     setosa
# 22            1.0     setosa
# 23            1.7     setosa
# 24            1.9     setosa
# 25            1.6     setosa
# 26            1.6     setosa
# 27            1.5     setosa
# 28            1.4     setosa
# 29            1.6     setosa
# ..            ...        ...
# ...

# %% [markdown]
# Below we will generate a table of descriptive statistics that show the general shape of the dataset's distribution.

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ref: { https://www.kaggle.com/jchen2186/machine-learning-with-iris-dataset <br/> https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.describe.html }

# %% [markdown]
# Already we can see that there are differences in petal length between the species of iris but as we'll see with further investagation this alone isn't enough to distinguish them.

# %%
# turn off a warning message
import warnings
warnings.filterwarnings('ignore')

# Seaborn is a python data visualization library based on matplotlib.
import seaborn as sns
import matplotlib.pyplot as plt


# Display graphs to show the overlap between the different species

sns.pairplot(df, hue='species')
plt.show()

# %%
# these graphs show just how similar the width and length can be with versicolor and virginica
sns.violinplot(y='species', x='sepal_length', data=df, inner='quartile')
plt.show()
sns.violinplot(y='species', x='sepal_width', data=df, inner='quartile')
plt.show()
sns.violinplot(y='species', x='petal_length', data=df, inner='quartile')
plt.show()
sns.violinplot(y='species', x='petal_width', data=df, inner='quartile')
plt.show()

# %% [markdown]
# ref: {https://www.kaggle.com/jchen2186/machine-learning-with-iris-dataset }
#
# So as we see the setosa are in most cases fairly different to the other two species. The problem is seperating the versicolor and virginica so the can be easily identifiable. There is a lot of overlap in some cases and this makes it difficult to quickly identify them from the graphs.
#
# For this reason the iris dataset is really useful for testing machine learning as there are two species that are very similar in a lot of respects so when shown to a human in a graph it isn't immediately obvious which is which. But we can use machine learning to solve this problem by teaching a neural network to understand the differences between the species.

# %% [markdown]
# End
